# %% [markdown]
# # STC Jawwy

# %%
"""
Here we install libraries that are not installed by default
Example:  pyslsb
Feel free to add any library you are planning to use.
"""
# !pip install pyxlsb

# %%
# Import the required libraries
"""
Please feel free to import any required libraries as per your needs
"""
import pandas as pd     # provides high-performance, easy to use structures and data analysis tools
import pyxlsb           # Excel extention to read xlsb files (the input file)
import numpy as np      # provides fast mathematical computation on arrays and matrices

# %% [markdown]
# # Jawwy dataset
# The dataset includes total watching hours for customers per day.
#
# You are required to work on predecting the forecast for the watching hours.

# %%
dataframe = pd.read_csv("stc TV Data Set_T2 .xlsx - Sheet1.csv",index_col=0)
# Please make a copy of dataset if you are going to work directly and make changes on the dataset
# you can use   df=dataframe.copy()

# %%
# check the data shape
dataframe.shape
# Out:
# (86, 2)

# %%
# display the first 5 rows
dataframe.head()
# Out:
#                  date_ Total_watch_time_in_houres
# 0  2018-01-01 00:00:00                1123٫551944
# 1  2018-01-02 00:00:00                1000٫129722
# 2  2018-01-03 00:00:00                881٫9244444
# 3  2018-01-04 00:00:00                782٫6694444
# 4  2018-01-05 00:00:00                1051٫939444

# %%
print(dataframes.columns)
# Out:
# Index(['date_', 'Total_watch_time_in_houres'], dtype='object')

# %%
print(dataframe['Total_watch_time_in_houres'].dtype)
print(dataframe['date_'].dtype)
# Out:
# object
# object

# %%
dataframe['Total_watch_time_in_houres'] = dataframe['Total_watch_time_in_houres'].str.replace('٫', '.', regex=False)
dataframe['Total_watch_time_in_houres'] = pd.to_numeric(dataframe['Total_watch_time_in_houres'], errors='coerce')

dataframe['date_'] = pd.to_datetime(dataframe['date_'], errors='coerce').dt.date

# %%
# display the dataset after applying data types
dataframe.head()
# Out:
#         date_  Total_watch_time_in_houres
# 0  2018-01-01                 1123.551944
# 1  2018-01-02                 1000.129722
# 2  2018-01-03                  881.924444
# 3  2018-01-04                  782.669444
# 4  2018-01-05                 1051.939444

# %%
# describe the numeric values in the dataset
dataframe.describe()
# Out:
#        Total_watch_time_in_houres
# count                   86.000000
# mean                   780.817926
# std                    122.992002
# min                    562.124722
# 25%                    707.709653
# 50%                    763.181389
# 75%                    840.985278
# max                   1123.551944

# %%
# check if any column has null value in the dataset
dataframe.isnull().any()
# Out:
# date_                         False
# Total_watch_time_in_houres    False
# dtype: bool

# %%
# we import Visualization libraries
# you can ignore and use any other graphing libraries
import matplotlib.pyplot as plt # a comprehensive library for creating static, animated, and interactive visualizations
import plotly #a graphing library makes interactive, publication-quality graphs. Examples of how to make line plots, scatter plots, area charts, bar charts, error bars, box plots, histograms, heatmaps, subplots, multiple-axes, polar charts, and bubble charts.
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# Setting the date as index
dataframe.set_index('date_', inplace=True)

# %%
# Display the dataframe after setting the date as index
dataframe.head()
# Out:
#             Total_watch_time_in_houres
# date_
# 2018-01-01                 1123.551944
# 2018-01-02                 1000.129722
# 2018-01-03                  881.924444
# 2018-01-04                  782.669444
# 2018-01-05                 1051.939444

# %%
# show the dataframe
fig = px.line(dataframe,  y="Total_watch_time_in_houres")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
TODO using the previous dataset (df) build a prediction model to predict the expected watch time for the next two months
Hint: you can build a forecast model to predict the results
"""
# Out:
# '\nTODO using the previous dataset (df) build a prediction model to predict the expected watch time for the next two months\nHint: you can build a forecast model to predict the results\n'

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

from statsmodels.tsa.arima.model import ARIMA

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86 entries, 2018-01-01 to 2018-04-30
# Data columns (total 1 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Total_watch_time_in_houres  86 non-null     float64
# dtypes: float64(1)
# memory usage: 1.3+ KB

# %%
dataframe.head()
# Out:
#             Total_watch_time_in_houres
# date_
# 2018-01-01                 1123.551944
# 2018-01-02                 1000.129722
# 2018-01-03                  881.924444
# 2018-01-04                  782.669444
# 2018-01-05                 1051.939444

# %%
dataframe['date_'] = pd.to_datetime(dataframe.index)
dataframe['date_ordinal'] = dataframe['date_'].map(pd.Timestamp.toordinal)

# %%
X = dataframe[['date_ordinal']]
y = dataframe['Total_watch_time_in_houres']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
pre = model.predict(x_test)
print (' mean_squared_error:  ' , mean_squared_error(y_test, pre), '  r2_score:  ', r2_score(y_test, pre), '  mean_absolute_error:  ',  mean_absolute_error(y_test, pre))
# Out:
#  mean_squared_error:   6.462348535570529e-27   r2_score:   1.0   mean_absolute_error:   3.157967714489334e-14

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(dataframe['Total_watch_time_in_houres'], order=(1, 1, 1))
model_fit = model.fit()
predictions = model_fit.forecast(steps=30)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency B will be used.
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency B will be used.
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency B will be used.

# %%
# !pip install prophet
from prophet import Prophet # changed fbprophet to prophet
df_prophet = dataframe.reset_index(drop=True).rename(columns={'date_': 'ds', 'Total_watch_time_in_houres': 'y'}) # Added drop=True to avoid the error
model = Prophet()
model.fit(df_prophet)
future = model.make_future_dataframe(periods=30)
forecast = model.predict(future)
# Out:
# ...
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8bimr5c6/p7r64npk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp8bimr5c6/dtsv3sse.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28298', 'data', 'file=/tmp/tmp8bimr5c6/p7r64npk.json', 'init=/tmp/tmp8bimr5c6/dtsv3sse.json', 'output', 'file=/tmp/tmp8bimr5c6/prophet_modeljv08z526/prophet_model-20240923135923.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 13:59:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:59:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
pre = m_fit.predict(start=len(x_train), end=len(x_train) + len(x_test) - 1)
print (' mean_squared_error:  ' , mean_squared_error(y_test, pre), '  r2_score:  ', r2_score(y_test, pre), '  mean_absolute_error:  ',  mean_absolute_error(y_test, pre))
# Out:
#  mean_squared_error:   24647.935835876055   r2_score:   -0.14537277771287527   mean_absolute_error:   133.64750359777497
